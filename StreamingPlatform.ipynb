# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('streaming_platform.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration  \
# 0     25-Sep-21          2020  PG-13     90 min
# 1     24-Sep-21          2021  TV-MA  2 Seasons
# 2     24-Sep-21          2021  TV-MA   1 Season
# 3     24-Sep-21          2021  TV-MA   1 Season
# 4     24-Sep-21          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# 8805  11-Jan-20          2006     PG     88 min
# 8806   2-Mar-19          2015  TV-14    111 min
#
#                                               listed_in  Unnamed: 11
# 0                                         Documentaries          NaN
# 1       International TV Shows, TV Dramas, TV Mysteries          NaN
# 2     Crime TV Shows, International TV Shows, TV Act...          NaN
# 3                                Docuseries, Reality TV          NaN
# 4     International TV Shows, Romantic TV Shows, TV ...          NaN
# ...                                                 ...          ...
# 8802                     Cult Movies, Dramas, Thrillers          NaN
# 8803             Kids' TV, Korean TV Shows, TV Comedies          NaN
# 8804                            Comedies, Horror Movies          NaN
# 8805                 Children & Family Movies, Comedies          NaN
# 8806     Dramas, International Movies, Music & Musicals          NaN
#
# [8807 rows x 12 columns]

# %% [markdown]
# # Dataset Structure Analysis and Treatment

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# Shape of data set: 8807 rows and 12 columns

# %% [markdown]
# Unknown and empty column is detected. Need to drop/delete it

# %%
df.drop(columns='Unnamed: 11', inplace=True)

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0  25-Sep-21          2020  PG-13     90 min
# 1  24-Sep-21          2021  TV-MA  2 Seasons
# 2  24-Sep-21          2021  TV-MA   1 Season
# 3  24-Sep-21          2021  TV-MA   1 Season
# 4  24-Sep-21          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %%
#Method to check count of clustered cell
df[df.director.apply(lambda x: ',' in str(x))].director.count()
# Out:
# 614

# %%
df[df.cast.apply(lambda x: ',' in str(x))].cast.count()
# Out:
# 7101

# %%
df[df.country.apply(lambda x: ',' in str(x))].country.count()
# Out:
# 1320

# %%
df[df.rating.apply(lambda x: ',' in str(x))].rating.count()
# Out:
# 0

# %%
df[df.listed_in.apply(lambda x: ',' in str(x))].listed_in.count()
# Out:
# 6787

# %%
df.type.unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 757.0+ KB

# %%
df.rating.value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# - Most of the columns are strings except release_year
# - We can also see that 3 rows in rating column should be in duration column which has 3 missing values.
# - title, director, cast, country, date_added, rating, duration column has null values. We can treat them by following below steps.
#     - title: Unknown_Title
#     - director: Unknown_Director
#     - cast: Unknown_Cast
#     - country: Unknown_Country
#     - date_added: 0
#     - rating: Unknown_Genre
# - It looks like some of the columns has mutiple names/values clustered and separator is ','. We need to disperse it for better analysis, those are: director, cast, country, listed_in. (some offical titles comes with ',' as a part of it so ignoring this column)
# - As there are only 2 types, Movie and TV Shows and it is noticed that all the duration of movies are in minutes and for TV Shows are in seasons, we need to make it in integer
# - date_added column needs to be in date format
# - Changing the column name of listed_in to genre

# %%
df[df.duration.isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States   4-Apr-17          2017  74 min      NaN
# 5794  Louis C.K.  United States  16-Sep-16          2010  84 min      NaN
# 5813  Louis C.K.  United States  15-Aug-16          2015  66 min      NaN
#
#      listed_in
# 5541    Movies
# 5794    Movies
# 5813    Movies

# %%
df['duration'].fillna(df[df['duration'].isna()]['rating'], inplace=True)

# %%
df.duration.isna().sum()
# Out:
# 0

# %%
df.loc[(df['rating'] == '74 min') | (df['rating'] == '84 min') | (df['rating'] == '66 min'), 'rating'] = None

# %%
df.rating.value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
df.title.fillna('Unknown_Title', inplace=True)
df.director.fillna('Unknown_Director', inplace=True)
df.cast.fillna('Unknown_Cast', inplace=True)
df.country.fillna('Unknown_Country', inplace=True)
df.date_added.fillna(0, inplace=True)
df.rating.fillna('Unknown_Genre', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 757.0+ KB

# %%
df
# Out:
#      show_id     type                  title          director  \
# 0         s1    Movie   Dick Johnson Is Dead   Kirsten Johnson
# 1         s2  TV Show          Blood & Water  Unknown_Director
# 2         s3  TV Show              Ganglands   Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  Unknown_Director
# 4         s5  TV Show           Kota Factory  Unknown_Director
# ...      ...      ...                    ...               ...
# 8802   s8803    Movie                 Zodiac     David Fincher
# 8803   s8804  TV Show            Zombie Dumb  Unknown_Director
# 8804   s8805    Movie             Zombieland   Ruben Fleischer
# 8805   s8806    Movie                   Zoom      Peter Hewitt
# 8806   s8807    Movie                 Zubaan       Mozez Singh
#
#                                                    cast          country  \
# 0                                          Unknown_Cast    United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...     South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Unknown_Country
# 3                                          Unknown_Cast  Unknown_Country
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...            India
# ...                                                 ...              ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...    United States
# 8803                                       Unknown_Cast  Unknown_Country
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...    United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...    United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...            India
#
#      date_added  release_year rating   duration  \
# 0     25-Sep-21          2020  PG-13     90 min
# 1     24-Sep-21          2021  TV-MA  2 Seasons
# 2     24-Sep-21          2021  TV-MA   1 Season
# 3     24-Sep-21          2021  TV-MA   1 Season
# 4     24-Sep-21          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# 8805  11-Jan-20          2006     PG     88 min
# 8806   2-Mar-19          2015  TV-14    111 min
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
# [8807 rows x 11 columns]

# %%
#checking a process
x='Ama Qamata, Khosi Ngema, Gail Mabalane'
x.split(', ')
# Out:
# ['Ama Qamata', 'Khosi Ngema', 'Gail Mabalane']

# %%
def cluster(x):
    return x.split(', ')

# %%
df.director=df.director.apply(cluster)
df.cast=df.cast.apply(cluster)
df.country=df.country.apply(cluster)
df.listed_in=df.listed_in.apply(cluster)
df
# Out:
#      show_id     type                  title            director  \
# 0         s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1         s2  TV Show          Blood & Water  [Unknown_Director]
# 2         s3  TV Show              Ganglands   [Julien Leclercq]
# 3         s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4         s5  TV Show           Kota Factory  [Unknown_Director]
# ...      ...      ...                    ...                 ...
# 8802   s8803    Movie                 Zodiac     [David Fincher]
# 8803   s8804  TV Show            Zombie Dumb  [Unknown_Director]
# 8804   s8805    Movie             Zombieland   [Ruben Fleischer]
# 8805   s8806    Movie                   Zoom      [Peter Hewitt]
# 8806   s8807    Movie                 Zubaan       [Mozez Singh]
#
#                                                    cast            country  \
# 0                                        [Unknown_Cast]    [United States]
# 1     [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2     [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                        [Unknown_Cast]  [Unknown_Country]
# 4     [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
# ...                                                 ...                ...
# 8802  [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...    [United States]
# 8803                                     [Unknown_Cast]  [Unknown_Country]
# 8804  [Jesse Eisenberg, Woody Harrelson, Emma Stone,...    [United States]
# 8805  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...    [United States]
# 8806  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...            [India]
#
#      date_added  release_year rating   duration  \
# 0     25-Sep-21          2020  PG-13     90 min
# 1     24-Sep-21          2021  TV-MA  2 Seasons
# 2     24-Sep-21          2021  TV-MA   1 Season
# 3     24-Sep-21          2021  TV-MA   1 Season
# 4     24-Sep-21          2021  TV-MA  2 Seasons
# ...         ...           ...    ...        ...
# 8802  20-Nov-19          2007      R    158 min
# 8803   1-Jul-19          2018  TV-Y7  2 Seasons
# 8804   1-Nov-19          2009      R     88 min
# 8805  11-Jan-20          2006     PG     88 min
# 8806   2-Mar-19          2015  TV-14    111 min
#
#                                               listed_in
# 0                                       [Documentaries]
# 1     [International TV Shows, TV Dramas, TV Mysteries]
# 2     [Crime TV Shows, International TV Shows, TV Ac...
# 3                              [Docuseries, Reality TV]
# 4     [International TV Shows, Romantic TV Shows, TV...
# ...                                                 ...
# 8802                   [Cult Movies, Dramas, Thrillers]
# 8803           [Kids' TV, Korean TV Shows, TV Comedies]
# 8804                          [Comedies, Horror Movies]
# 8805               [Children & Family Movies, Comedies]
# 8806   [Dramas, International Movies, Music & Musicals]
#
# [8807 rows x 11 columns]

# %%
def chang(x):
    return x.split(" ")[0]

# %%
df.duration = df.duration.astype(str)
df.duration = df.duration.apply(chang)
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water  [Unknown_Director]
# 2      s3  TV Show              Ganglands   [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4      s5  TV Show           Kota Factory  [Unknown_Director]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                     [Unknown_Cast]  [Unknown_Country]
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
#
#   date_added  release_year rating duration  \
# 0  25-Sep-21          2020  PG-13       90
# 1  24-Sep-21          2021  TV-MA        2
# 2  24-Sep-21          2021  TV-MA        1
# 3  24-Sep-21          2021  TV-MA        1
# 4  24-Sep-21          2021  TV-MA        2
#
#                                            listed_in
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...
# 3                           [Docuseries, Reality TV]
# 4  [International TV Shows, Romantic TV Shows, TV...

# %%
#changing the format to Integer
df.duration = df.duration.astype(int)

# %%
df.date_added=pd.to_datetime(df.date_added)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   int32
#  10  listed_in     8807 non-null   object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(8)
# memory usage: 722.6+ KB

# %%
df.rename(columns={'listed_in':'genre'}, inplace=True)

# %% [markdown]
# ## Intial Analysis

# %%
df.head(3)
# Out:
#   show_id     type                 title            director  \
# 0      s1    Movie  Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show         Blood & Water  [Unknown_Director]
# 2      s3  TV Show             Ganglands   [Julien Leclercq]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
#
#                                                genre
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...

# %%
df.type.value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
plt.pie(df.type.value_counts(), labels=df.type.value_counts().index, autopct='%.0f%%')
plt.show()

# %%
df_dir=df
df_dir=df_dir.explode('director', ignore_index=True)
df_dir.head(3)
# Out:
#   show_id     type                 title          director  \
# 0      s1    Movie  Dick Johnson Is Dead   Kirsten Johnson
# 1      s2  TV Show         Blood & Water  Unknown_Director
# 2      s3  TV Show             Ganglands   Julien Leclercq
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
#
#                                                genre
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...

# %%
df_dir.director.value_counts()
# Out:
# director
# Unknown_Director    2634
# Rajiv Chilaka         22
# Jan Suter             21
# Raúl Campos           19
# Suhas Kadav           16
#                     ...
# Raymie Muzquiz         1
# Stu Livingston         1
# Joe Menendez           1
# Eric Bross             1
# Mozez Singh            1
# Name: count, Length: 4994, dtype: int64

# %%
df_dir=df_dir[df_dir.director!='Unknown_Director']
df_dir
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 2         s3  TV Show                         Ganglands  Julien Leclercq
# 5         s6  TV Show                     Midnight Mass    Mike Flanagan
# 6         s7    Movie  My Little Pony: A New Generation    Robert Cullen
# 7         s7    Movie  My Little Pony: A New Generation   José Luis Ucha
# ...      ...      ...                               ...              ...
# 9606   s8802    Movie                           Zinzana  Majid Al Ansari
# 9607   s8803    Movie                            Zodiac    David Fincher
# 9609   s8805    Movie                        Zombieland  Ruben Fleischer
# 9610   s8806    Movie                              Zoom     Peter Hewitt
# 9611   s8807    Movie                            Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                        [Unknown_Cast]
# 2     [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...
# 5     [Kate Siegel, Zach Gilford, Hamish Linklater, ...
# 6     [Vanessa Hudgens, Kimiko Glenn, James Marsden,...
# 7     [Vanessa Hudgens, Kimiko Glenn, James Marsden,...
# ...                                                 ...
# 9606  [Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri,...
# 9607  [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...
# 9609  [Jesse Eisenberg, Woody Harrelson, Emma Stone,...
# 9610  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...
# 9611  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...
#
#                              country date_added  release_year rating  \
# 0                    [United States] 2021-09-25          2020  PG-13
# 2                  [Unknown_Country] 2021-09-24          2021  TV-MA
# 5                  [Unknown_Country] 2021-09-24          2021  TV-MA
# 6                  [Unknown_Country] 2021-09-24          2021     PG
# 7                  [Unknown_Country] 2021-09-24          2021     PG
# ...                              ...        ...           ...    ...
# 9606  [United Arab Emirates, Jordan] 2016-03-09          2015  TV-MA
# 9607                 [United States] 2019-11-20          2007      R
# 9609                 [United States] 2019-11-01          2009      R
# 9610                 [United States] 2020-01-11          2006     PG
# 9611                         [India] 2019-03-02          2015  TV-14
#
#       duration                                              genre
# 0           90                                    [Documentaries]
# 2            1  [Crime TV Shows, International TV Shows, TV Ac...
# 5            1               [TV Dramas, TV Horror, TV Mysteries]
# 6           91                         [Children & Family Movies]
# 7           91                         [Children & Family Movies]
# ...        ...                                                ...
# 9606        96          [Dramas, International Movies, Thrillers]
# 9607       158                   [Cult Movies, Dramas, Thrillers]
# 9609        88                          [Comedies, Horror Movies]
# 9610        88               [Children & Family Movies, Comedies]
# 9611       111   [Dramas, International Movies, Music & Musicals]
#
# [6978 rows x 11 columns]

# %%
df_dir.director.value_counts()[:10]
# Out:
# director
# Rajiv Chilaka          22
# Jan Suter              21
# Raúl Campos            19
# Suhas Kadav            16
# Marcus Raboy           16
# Jay Karas              15
# Cathy Garcia-Molina    13
# Jay Chapman            12
# Youssef Chahine        12
# Martin Scorsese        12
# Name: count, dtype: int64

# %%
# Top 10 Directors
df_dir.director.value_counts()[:10].plot(kind='bar');

# %%
df_dir[df_dir.type=='Movie'].director.value_counts()[:10]
# Out:
# director
# Rajiv Chilaka          22
# Jan Suter              21
# Raúl Campos            19
# Suhas Kadav            16
# Marcus Raboy           15
# Jay Karas              15
# Cathy Garcia-Molina    13
# Martin Scorsese        12
# Youssef Chahine        12
# Jay Chapman            12
# Name: count, dtype: int64

# %%
# Top 10 Movie Directors 
df_dir[df_dir.type=='Movie'].director.value_counts()[:10].plot(kind='bar');

# %%
df_dir[df_dir.type=='TV Show'].director.value_counts()[:10]
# Out:
# director
# Alastair Fothergill      3
# Ken Burns                3
# Jung-ah Im               2
# Gautham Vasudev Menon    2
# Iginio Straffi           2
# Hsu Fu-chun              2
# Stan Lathan              2
# Joe Berlinger            2
# Shin Won-ho              2
# Lynn Novick              2
# Name: count, dtype: int64

# %%
# Top 10 TV Show Directors
df_dir[df_dir.type=='TV Show'].director.value_counts()[:10].plot(kind='bar');

# %%
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water  [Unknown_Director]
# 2      s3  TV Show              Ganglands   [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4      s5  TV Show           Kota Factory  [Unknown_Director]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                     [Unknown_Cast]  [Unknown_Country]
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
# 3 2021-09-24          2021  TV-MA         1
# 4 2021-09-24          2021  TV-MA         2
#
#                                                genre
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...
# 3                           [Docuseries, Reality TV]
# 4  [International TV Shows, Romantic TV Shows, TV...

# %%
df_cast=df
df_cast=df_cast.explode('cast', ignore_index=True)
df_cast.head(3)
# Out:
#   show_id     type                 title            director          cast  \
# 0      s1    Movie  Dick Johnson Is Dead   [Kirsten Johnson]  Unknown_Cast
# 1      s2  TV Show         Blood & Water  [Unknown_Director]    Ama Qamata
# 2      s2  TV Show         Blood & Water  [Unknown_Director]   Khosi Ngema
#
#            country date_added  release_year rating  duration  \
# 0  [United States] 2021-09-25          2020  PG-13        90
# 1   [South Africa] 2021-09-24          2021  TV-MA         2
# 2   [South Africa] 2021-09-24          2021  TV-MA         2
#
#                                                genre
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [International TV Shows, TV Dramas, TV Mysteries]

# %%
df_cast=df_cast[df_cast.cast!='Unknown_Cast']
df_cast
# Out:
#       show_id     type          title            director  \
# 1          s2  TV Show  Blood & Water  [Unknown_Director]
# 2          s2  TV Show  Blood & Water  [Unknown_Director]
# 3          s2  TV Show  Blood & Water  [Unknown_Director]
# 4          s2  TV Show  Blood & Water  [Unknown_Director]
# 5          s2  TV Show  Blood & Water  [Unknown_Director]
# ...       ...      ...            ...                 ...
# 64946   s8807    Movie         Zubaan       [Mozez Singh]
# 64947   s8807    Movie         Zubaan       [Mozez Singh]
# 64948   s8807    Movie         Zubaan       [Mozez Singh]
# 64949   s8807    Movie         Zubaan       [Mozez Singh]
# 64950   s8807    Movie         Zubaan       [Mozez Singh]
#
#                         cast         country date_added  release_year rating  \
# 1                 Ama Qamata  [South Africa] 2021-09-24          2021  TV-MA
# 2                Khosi Ngema  [South Africa] 2021-09-24          2021  TV-MA
# 3              Gail Mabalane  [South Africa] 2021-09-24          2021  TV-MA
# 4             Thabang Molaba  [South Africa] 2021-09-24          2021  TV-MA
# 5           Dillon Windvogel  [South Africa] 2021-09-24          2021  TV-MA
# ...                      ...             ...        ...           ...    ...
# 64946       Manish Chaudhary         [India] 2019-03-02          2015  TV-14
# 64947           Meghna Malik         [India] 2019-03-02          2015  TV-14
# 64948          Malkeet Rauni         [India] 2019-03-02          2015  TV-14
# 64949         Anita Shabdish         [India] 2019-03-02          2015  TV-14
# 64950  Chittaranjan Tripathy         [India] 2019-03-02          2015  TV-14
#
#        duration                                              genre
# 1             2  [International TV Shows, TV Dramas, TV Mysteries]
# 2             2  [International TV Shows, TV Dramas, TV Mysteries]
# 3             2  [International TV Shows, TV Dramas, TV Mysteries]
# 4             2  [International TV Shows, TV Dramas, TV Mysteries]
# 5             2  [International TV Shows, TV Dramas, TV Mysteries]
# ...         ...                                                ...
# 64946       111   [Dramas, International Movies, Music & Musicals]
# 64947       111   [Dramas, International Movies, Music & Musicals]
# 64948       111   [Dramas, International Movies, Music & Musicals]
# 64949       111   [Dramas, International Movies, Music & Musicals]
# 64950       111   [Dramas, International Movies, Music & Musicals]
#
# [64126 rows x 11 columns]

# %%
df_cast.cast.value_counts()[:10]
# Out:
# cast
# Anupam Kher         43
# Shah Rukh Khan      35
# Julie Tejwani       33
# Naseeruddin Shah    32
# Takahiro Sakurai    32
# Rupa Bhimani        31
# Akshay Kumar        30
# Om Puri             30
# Yuki Kaji           29
# Paresh Rawal        28
# Name: count, dtype: int64

# %%
df_cast.cast.value_counts()[:10].plot(kind='bar');

# %%
df_cast[df_cast.type=='Movie'].cast.value_counts()[:10]
# Out:
# cast
# Anupam Kher         42
# Shah Rukh Khan      35
# Naseeruddin Shah    32
# Akshay Kumar        30
# Om Puri             30
# Amitabh Bachchan    28
# Julie Tejwani       28
# Paresh Rawal        28
# Rupa Bhimani        27
# Boman Irani         27
# Name: count, dtype: int64

# %%
df_cast[df_cast.type=='Movie'].cast.value_counts()[:10].plot(kind='bar');

# %%
df_cast[df_cast.type=='TV Show'].cast.value_counts()[:10]
# Out:
# cast
# Takahiro Sakurai      25
# Yuki Kaji             19
# Daisuke Ono           17
# Junichi Suwabe        17
# Ai Kayano             17
# Yuichi Nakamura       16
# Jun Fukuyama          15
# Yoshimasa Hosoya      15
# David Attenborough    14
# Mamoru Miyano         13
# Name: count, dtype: int64

# %%
df_cast[df_cast.type=='TV Show'].cast.value_counts()[:10].plot(kind='bar');

# %%
df_cnty=df
df_cnty=df_cnty.explode('country', ignore_index=True)
df_cnty=df_cnty[df_cnty.country!='Unknown_Country']
df_cnty
# Out:
#       show_id     type                 title            director  \
# 0          s1    Movie  Dick Johnson Is Dead   [Kirsten Johnson]
# 1          s2  TV Show         Blood & Water  [Unknown_Director]
# 4          s5  TV Show          Kota Factory  [Unknown_Director]
# 7          s8    Movie               Sankofa      [Haile Gerima]
# 8          s8    Movie               Sankofa      [Haile Gerima]
# ...       ...      ...                   ...                 ...
# 10839   s8802    Movie               Zinzana   [Majid Al Ansari]
# 10840   s8803    Movie                Zodiac     [David Fincher]
# 10842   s8805    Movie            Zombieland   [Ruben Fleischer]
# 10843   s8806    Movie                  Zoom      [Peter Hewitt]
# 10844   s8807    Movie                Zubaan       [Mozez Singh]
#
#                                                     cast        country  \
# 0                                         [Unknown_Cast]  United States
# 1      [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...   South Africa
# 4      [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...          India
# 7      [Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra ...  United States
# 8      [Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra ...          Ghana
# ...                                                  ...            ...
# 10839  [Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri,...         Jordan
# 10840  [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...  United States
# 10842  [Jesse Eisenberg, Woody Harrelson, Emma Stone,...  United States
# 10843  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...  United States
# 10844  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...          India
#
#       date_added  release_year rating  duration  \
# 0     2021-09-25          2020  PG-13        90
# 1     2021-09-24          2021  TV-MA         2
# 4     2021-09-24          2021  TV-MA         2
# 7     2021-09-24          1993  TV-MA       125
# 8     2021-09-24          1993  TV-MA       125
# ...          ...           ...    ...       ...
# 10839 2016-03-09          2015  TV-MA        96
# 10840 2019-11-20          2007      R       158
# 10842 2019-11-01          2009      R        88
# 10843 2020-01-11          2006     PG        88
# 10844 2019-03-02          2015  TV-14       111
#
#                                                    genre
# 0                                        [Documentaries]
# 1      [International TV Shows, TV Dramas, TV Mysteries]
# 4      [International TV Shows, Romantic TV Shows, TV...
# 7      [Dramas, Independent Movies, International Mov...
# 8      [Dramas, Independent Movies, International Mov...
# ...                                                  ...
# 10839          [Dramas, International Movies, Thrillers]
# 10840                   [Cult Movies, Dramas, Thrillers]
# 10842                          [Comedies, Horror Movies]
# 10843               [Children & Family Movies, Comedies]
# 10844   [Dramas, International Movies, Music & Musicals]
#
# [10014 rows x 11 columns]

# %%
df_cnty.country.value_counts()[:10]
# Out:
# country
# United States     3689
# India             1046
# United Kingdom     804
# Canada             445
# France             393
# Japan              318
# Spain              232
# South Korea        231
# Germany            226
# Mexico             169
# Name: count, dtype: int64

# %%
df_cnty.country.value_counts()[:10].plot(kind='bar');

# %%
df_cnty[df_cnty.type=='Movie'].country.value_counts()[:10]
# Out:
# country
# United States     2751
# India              962
# United Kingdom     532
# Canada             319
# France             303
# Germany            182
# Spain              171
# Japan              119
# China              114
# Mexico             111
# Name: count, dtype: int64

# %%
df_cnty[df_cnty.type=='Movie'].country.value_counts()[:10].plot(kind='bar');

# %%
df_cnty[df_cnty.type=='TV Show'].country.value_counts()[:10]
# Out:
# country
# United States     938
# United Kingdom    272
# Japan             199
# South Korea       170
# Canada            126
# France             90
# India              84
# Taiwan             70
# Australia          66
# Spain              61
# Name: count, dtype: int64

# %%
df_cnty[df_cnty.type=='TV Show'].country.value_counts()[:10].plot(kind='bar');

# %%
df.rating.value_counts()
# Out:
# rating
# TV-MA            3207
# TV-14            2160
# TV-PG             863
# R                 799
# PG-13             490
# TV-Y7             334
# TV-Y              307
# PG                287
# TV-G              220
# NR                 80
# G                  41
# Unknown_Genre       7
# TV-Y7-FV            6
# NC-17               3
# UR                  3
# Name: count, dtype: int64

# %%
plt.pie(df.rating.value_counts()[:10], labels=df.rating.value_counts()[:10].index, autopct='%.0f%%')
plt.show()

# %%
df_gen=df
df_gen=df_gen.explode('genre', ignore_index=True)
df_gen
# Out:
#       show_id     type                 title            director  \
# 0          s1    Movie  Dick Johnson Is Dead   [Kirsten Johnson]
# 1          s2  TV Show         Blood & Water  [Unknown_Director]
# 2          s2  TV Show         Blood & Water  [Unknown_Director]
# 3          s2  TV Show         Blood & Water  [Unknown_Director]
# 4          s3  TV Show             Ganglands   [Julien Leclercq]
# ...       ...      ...                   ...                 ...
# 19318   s8806    Movie                  Zoom      [Peter Hewitt]
# 19319   s8806    Movie                  Zoom      [Peter Hewitt]
# 19320   s8807    Movie                Zubaan       [Mozez Singh]
# 19321   s8807    Movie                Zubaan       [Mozez Singh]
# 19322   s8807    Movie                Zubaan       [Mozez Singh]
#
#                                                     cast            country  \
# 0                                         [Unknown_Cast]    [United States]
# 1      [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2      [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 3      [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 4      [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# ...                                                  ...                ...
# 19318  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...    [United States]
# 19319  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...    [United States]
# 19320  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...            [India]
# 19321  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...            [India]
# 19322  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...            [India]
#
#       date_added  release_year rating  duration                     genre
# 0     2021-09-25          2020  PG-13        90             Documentaries
# 1     2021-09-24          2021  TV-MA         2    International TV Shows
# 2     2021-09-24          2021  TV-MA         2                 TV Dramas
# 3     2021-09-24          2021  TV-MA         2              TV Mysteries
# 4     2021-09-24          2021  TV-MA         1            Crime TV Shows
# ...          ...           ...    ...       ...                       ...
# 19318 2020-01-11          2006     PG        88  Children & Family Movies
# 19319 2020-01-11          2006     PG        88                  Comedies
# 19320 2019-03-02          2015  TV-14       111                    Dramas
# 19321 2019-03-02          2015  TV-14       111      International Movies
# 19322 2019-03-02          2015  TV-14       111          Music & Musicals
#
# [19323 rows x 11 columns]

# %%
df_gen.genre.value_counts()[:10]
# Out:
# genre
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
df_gen.genre.value_counts().plot(kind='bar');

# %%
df_gen[df_gen.date_added.dt.year>=2019].genre.value_counts()
# Out:
# genre
# International Movies            1593
# Dramas                          1511
# Comedies                        1135
# International TV Shows           841
# Action & Adventure               568
# TV Dramas                        465
# Children & Family Movies         439
# Independent Movies               438
# Romantic Movies                  437
# Documentaries                    405
# Thrillers                        380
# TV Comedies                      361
# Crime TV Shows                   290
# Kids' TV                         289
# Docuseries                       240
# Horror Movies                    232
# Romantic TV Shows                223
# Music & Musicals                 206
# Reality TV                       194
# Sci-Fi & Fantasy                 155
# British TV Shows                 136
# Stand-Up Comedy                  131
# Anime Series                     128
# Sports Movies                    127
# TV Action & Adventure            120
# Spanish-Language TV Shows        117
# Classic Movies                    95
# Korean TV Shows                   93
# TV Mysteries                      66
# LGBTQ Movies                      63
# TV Sci-Fi & Fantasy               58
# Teen TV Shows                     55
# TV Horror                         54
# Cult Movies                       53
# Anime Features                    51
# Science & Nature TV               47
# TV Thrillers                      39
# Faith & Spirituality              38
# Stand-Up Comedy & Talk Shows      25
# Movies                            19
# TV Shows                          10
# Classic & Cult TV                 10
# Name: count, dtype: int64

# %%
#Last 3 years
plt.figure(figsize=(10,3))
sns.histplot(df_gen[df_gen.date_added.dt.year>=2019].genre)
plt.xticks(rotation=90);

# %%
df_gen[df_gen.type=='Movie'].genre.value_counts()
# Out:
# genre
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# Documentaries                869
# Action & Adventure           859
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Thrillers                    577
# Music & Musicals             375
# Horror Movies                357
# Stand-Up Comedy              343
# Sci-Fi & Fantasy             243
# Sports Movies                219
# Classic Movies               116
# LGBTQ Movies                 102
# Anime Features                71
# Cult Movies                   71
# Faith & Spirituality          65
# Movies                        57
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
df_gen[df_gen.type=='Movie'].genre.value_counts().plot(kind='bar');

# %%
df_gen[df_gen.type=='TV Show'].genre.value_counts()
# Out:
# genre
# International TV Shows          1351
# TV Dramas                        763
# TV Comedies                      581
# Crime TV Shows                   470
# Kids' TV                         451
# Docuseries                       395
# Romantic TV Shows                370
# Reality TV                       255
# British TV Shows                 253
# Anime Series                     176
# Spanish-Language TV Shows        174
# TV Action & Adventure            168
# Korean TV Shows                  151
# TV Mysteries                      98
# Science & Nature TV               92
# TV Sci-Fi & Fantasy               84
# TV Horror                         75
# Teen TV Shows                     69
# TV Thrillers                      57
# Stand-Up Comedy & Talk Shows      56
# Classic & Cult TV                 28
# TV Shows                          16
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
df_gen[df_gen.type=='TV Show'].genre.value_counts().plot(kind='bar');

# %%
df_gen1=df_gen
df_gen1=df_gen1.explode('country', ignore_index=True)
df_gen1.head()
# Out:
#   show_id     type                 title            director  \
# 0      s1    Movie  Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show         Blood & Water  [Unknown_Director]
# 2      s2  TV Show         Blood & Water  [Unknown_Director]
# 3      s2  TV Show         Blood & Water  [Unknown_Director]
# 4      s3  TV Show             Ganglands   [Julien Leclercq]
#
#                                                 cast          country  \
# 0                                     [Unknown_Cast]    United States
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     South Africa
# 2  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     South Africa
# 3  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     South Africa
# 4  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  Unknown_Country
#
#   date_added  release_year rating  duration                   genre
# 0 2021-09-25          2020  PG-13        90           Documentaries
# 1 2021-09-24          2021  TV-MA         2  International TV Shows
# 2 2021-09-24          2021  TV-MA         2               TV Dramas
# 3 2021-09-24          2021  TV-MA         2            TV Mysteries
# 4 2021-09-24          2021  TV-MA         1          Crime TV Shows

# %%
#Filtering top 10 countries
df_gen1=df_gen1[df_gen1.country.isin(list(df_cnty.country.value_counts()[:10].index))]

# %%
#filtering top 10 genres
df_gen1=df_gen1[df_gen1.genre.isin(list(df_gen.genre.value_counts()[:10].index))]

# %%
pd.crosstab(df_gen1.country, df_gen1.genre)
# Out:
# genre           Action & Adventure  Children & Family Movies  Comedies  \
# country
# Canada                          44                        80        94
# France                          37                        23        51
# Germany                         33                        17        42
# India                          137                        26       323
# Japan                           57                        19         9
# Mexico                           9                         5        24
# South Korea                     17                        10        17
# Spain                           10                         9        47
# United Kingdom                  84                        46        91
# United States                  404                       390       680
#
# genre           Documentaries  Dramas  Independent Movies  \
# country
# Canada                     42      82                  44
# France                     44     167                  73
# Germany                    21      80                  31
# India                      27     662                 167
# Japan                       7      23                   7
# Mexico                     18      44                  23
# South Korea                 2      26                   2
# Spain                      21      76                  20
# United Kingdom            127     196                  74
# United States             511     835                 390
#
# genre           International Movies  International TV Shows  Romantic Movies  \
# country
# Canada                            60                      25               25
# France                           207                      43               22
# Germany                           94                      35               10
# India                            864                      66              120
# Japan                             72                     151                7
# Mexico                            70                      43                8
# South Korea                       44                     152                2
# Spain                            140                      54               11
# United Kingdom                   168                     128               38
# United States                    166                      74              225
#
# genre           TV Dramas
# country
# Canada                 32
# France                 27
# Germany                19
# India                  28
# Japan                  21
# Mexico                 12
# South Korea            38
# Spain                  11
# United Kingdom         36
# United States         232

# %%
sns.heatmap(pd.crosstab(df_gen1.country, df_gen1.genre), cmap='Blues');

# %% [markdown]
# As the release date is in years then to do analysis we need date_added in years

# %%
df['year_added']=df.date_added.dt.year
df.year_added.astype(int)
df
# Out:
#      show_id     type                  title            director  \
# 0         s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1         s2  TV Show          Blood & Water  [Unknown_Director]
# 2         s3  TV Show              Ganglands   [Julien Leclercq]
# 3         s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4         s5  TV Show           Kota Factory  [Unknown_Director]
# ...      ...      ...                    ...                 ...
# 8802   s8803    Movie                 Zodiac     [David Fincher]
# 8803   s8804  TV Show            Zombie Dumb  [Unknown_Director]
# 8804   s8805    Movie             Zombieland   [Ruben Fleischer]
# 8805   s8806    Movie                   Zoom      [Peter Hewitt]
# 8806   s8807    Movie                 Zubaan       [Mozez Singh]
#
#                                                    cast            country  \
# 0                                        [Unknown_Cast]    [United States]
# 1     [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2     [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                        [Unknown_Cast]  [Unknown_Country]
# 4     [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
# ...                                                 ...                ...
# 8802  [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...    [United States]
# 8803                                     [Unknown_Cast]  [Unknown_Country]
# 8804  [Jesse Eisenberg, Woody Harrelson, Emma Stone,...    [United States]
# 8805  [Tim Allen, Courteney Cox, Chevy Chase, Kate M...    [United States]
# 8806  [Vicky Kaushal, Sarah-Jane Dias, Raaghav Chana...            [India]
#
#      date_added  release_year rating  duration  \
# 0    2021-09-25          2020  PG-13        90
# 1    2021-09-24          2021  TV-MA         2
# 2    2021-09-24          2021  TV-MA         1
# 3    2021-09-24          2021  TV-MA         1
# 4    2021-09-24          2021  TV-MA         2
# ...         ...           ...    ...       ...
# 8802 2019-11-20          2007      R       158
# 8803 2019-07-01          2018  TV-Y7         2
# 8804 2019-11-01          2009      R        88
# 8805 2020-01-11          2006     PG        88
# 8806 2019-03-02          2015  TV-14       111
#
#                                                   genre  year_added
# 0                                       [Documentaries]        2021
# 1     [International TV Shows, TV Dramas, TV Mysteries]        2021
# 2     [Crime TV Shows, International TV Shows, TV Ac...        2021
# 3                              [Docuseries, Reality TV]        2021
# 4     [International TV Shows, Romantic TV Shows, TV...        2021
# ...                                                 ...         ...
# 8802                   [Cult Movies, Dramas, Thrillers]        2019
# 8803           [Kids' TV, Korean TV Shows, TV Comedies]        2019
# 8804                          [Comedies, Horror Movies]        2019
# 8805               [Children & Family Movies, Comedies]        2020
# 8806   [Dramas, International Movies, Music & Musicals]        2019
#
# [8807 rows x 12 columns]

# %%
sns.boxplot(df.year_added)
# Out:
# <Axes: ylabel='year_added'>

# %%
df.year_added.max(), df.year_added.min()
# Out:
# (2021, 1970)

# %%
df[['release_year', 'year_added']].describe()
# Out:
#        release_year   year_added
# count   8807.000000  8807.000000
# mean    2014.180198  2018.816396
# std        8.819312     2.276985
# min     1925.000000  1970.000000
# 25%     2013.000000  2018.000000
# 50%     2017.000000  2019.000000
# 75%     2019.000000  2020.000000
# max     2021.000000  2021.000000

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='date_added', kde=True);

# %% [markdown]
# Due to very low min value of Year added, we will use IQR method to deal with outliner

# %%
#Whisker values low, high
int(2018-1.5*(2020-2018)), int(1.5*(2020-2018)+2020)
# Out:
# (2015, 2023)

# %%
#As we do not have any outliner at the higher end so we will only limiting the lower side at 2015
sns.histplot(data=df[df.year_added>=2015], x='date_added', kde=True);

# %%
sns.boxplot(df.release_year)
# Out:
# <Axes: ylabel='release_year'>

# %% [markdown]
# Due to very low min value of Year added, we will use IQR mthod to deal with outliner

# %%
low, high=df.release_year.quantile([.09,1])
sns.boxplot(df.release_year.clip(low, high)), low
# Out:
# (<Axes: ylabel='release_year'>, 2005.0)

# %%
sns.histplot(data=df.release_year.clip(low, high), kde=True);

# %%
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water  [Unknown_Director]
# 2      s3  TV Show              Ganglands   [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4      s5  TV Show           Kota Factory  [Unknown_Director]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                     [Unknown_Cast]  [Unknown_Country]
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
# 3 2021-09-24          2021  TV-MA         1
# 4 2021-09-24          2021  TV-MA         2
#
#                                                genre  year_added
# 0                                    [Documentaries]        2021
# 1  [International TV Shows, TV Dramas, TV Mysteries]        2021
# 2  [Crime TV Shows, International TV Shows, TV Ac...        2021
# 3                           [Docuseries, Reality TV]        2021
# 4  [International TV Shows, Romantic TV Shows, TV...        2021

# %%
df['release_week']=df.date_added.dt.isocalendar().week
df['release_month']=df.date_added.dt.month
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water  [Unknown_Director]
# 2      s3  TV Show              Ganglands   [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4      s5  TV Show           Kota Factory  [Unknown_Director]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                     [Unknown_Cast]  [Unknown_Country]
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
# 3 2021-09-24          2021  TV-MA         1
# 4 2021-09-24          2021  TV-MA         2
#
#                                                genre  year_added  \
# 0                                    [Documentaries]        2021
# 1  [International TV Shows, TV Dramas, TV Mysteries]        2021
# 2  [Crime TV Shows, International TV Shows, TV Ac...        2021
# 3                           [Docuseries, Reality TV]        2021
# 4  [International TV Shows, Romantic TV Shows, TV...        2021
#
#    release_week  release_month
# 0            38              9
# 1            38              9
# 2            38              9
# 3            38              9
# 4            38              9

# %%
df.release_week.value_counts()
# Out:
# release_week
# 1     382
# 44    318
# 40    287
# 31    268
# 26    268
# 35    263
# 9     254
# 13    250
# 27    240
# 18    234
# 5     208
# 22    206
# 48    199
# 50    189
# 37    183
# 14    173
# 39    166
# 24    164
# 11    163
# 16    160
# 30    160
# 17    154
# 33    153
# 15    152
# 23    151
# 7     147
# 25    143
# 34    143
# 36    142
# 49    140
# 29    140
# 38    139
# 51    137
# 10    135
# 42    135
# 46    134
# 52    132
# 20    131
# 28    130
# 32    122
# 47    120
# 21    117
# 41    116
# 19    116
# 43    116
# 3     113
# 8     110
# 12    109
# 2     108
# 53    104
# 45     98
# 6      97
# 4      88
# Name: count, dtype: Int64

# %%
df.release_month.value_counts()
# Out:
# release_month
# 7     827
# 12    813
# 9     770
# 4     764
# 10    760
# 8     755
# 1     748
# 3     742
# 6     728
# 11    705
# 5     632
# 2     563
# Name: count, dtype: int64

# %%
df.release_week.value_counts().sort_values(ascending=False)[:10]
# Out:
# release_week
# 1     382
# 44    318
# 40    287
# 31    268
# 26    268
# 35    263
# 9     254
# 13    250
# 27    240
# 18    234
# Name: count, dtype: Int64

# %%
plt.subplot(1,2,1)
sns.histplot(df.release_week, kde=True)
plt.subplot(1,2,2)
df.release_week.value_counts().sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='release_week'>

# %%
plt.subplot(1,2,1)
sns.histplot(df.release_month, kde=True)
plt.subplot(1,2,2)
df.release_month.value_counts().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='release_month'>

# %%
df[df.type=='Movie'].release_week.value_counts()
# Out:
# release_week
# 1     316
# 44    243
# 40    215
# 9     207
# 26    195
# 35    189
# 31    185
# 13    174
# 18    173
# 27    154
# 22    146
# 48    139
# 5     135
# 16    124
# 14    124
# 50    119
# 30    116
# 11    115
# 37    114
# 23    112
# 39    111
# 17    109
# 10    107
# 7     106
# 33    105
# 34    102
# 25    101
# 15    100
# 36     97
# 49     95
# 29     94
# 42     90
# 24     89
# 28     89
# 43     88
# 38     88
# 51     86
# 47     85
# 20     85
# 41     84
# 46     83
# 3      81
# 52     80
# 2      78
# 21     76
# 19     73
# 32     73
# 8      72
# 12     67
# 6      64
# 45     61
# 53     61
# 4      56
# Name: count, dtype: Int64

# %%
df[df.type=='TV Show'].release_week.value_counts()
# Out:
# release_week
# 27    86
# 31    83
# 13    76
# 44    75
# 24    75
# 35    74
# 26    73
# 5     73
# 40    72
# 50    70
# 37    69
# 1     66
# 18    61
# 22    60
# 48    60
# 39    55
# 52    52
# 15    52
# 51    51
# 46    51
# 38    51
# 14    49
# 32    49
# 11    48
# 33    48
# 9     47
# 20    46
# 29    46
# 17    45
# 36    45
# 42    45
# 49    45
# 30    44
# 53    43
# 19    43
# 25    42
# 12    42
# 21    41
# 28    41
# 34    41
# 7     41
# 23    39
# 8     38
# 45    37
# 16    36
# 47    35
# 6     33
# 4     32
# 41    32
# 3     32
# 2     30
# 43    28
# 10    28
# Name: count, dtype: Int64

# %%
# Week distribution of Movie and TV Shows Added
plt.figure(figsize=(10,12))
plt.subplot(2,2,1)
sns.histplot(df[df.type=='Movie'].release_week, kde=True)
plt.title('Movie-Week')
plt.subplot(2,2,2)
df[df.type=='Movie'].release_week.value_counts().sort_values(ascending=False)[:10].plot(kind='bar')
plt.title('Movie-Week')
plt.subplot(2,2,3)
sns.histplot(df[df.type=='TV Show'].release_week, kde=True)
plt.title('TV Show-Week')
plt.subplot(2,2,4)
df[df.type=='TV Show'].release_week.value_counts().sort_values(ascending=False)[:10].plot(kind='bar')
plt.title('TV Show-Week');

# %%
df[df.type=='Movie'].release_month.value_counts()
# Out:
# release_month
# 7     565
# 4     550
# 12    547
# 1     546
# 10    545
# 3     529
# 9     519
# 8     519
# 11    498
# 6     492
# 5     439
# 2     382
# Name: count, dtype: int64

# %%
df[df.type=='TV Show'].release_month.value_counts()
# Out:
# release_month
# 12    266
# 7     262
# 9     251
# 8     236
# 6     236
# 10    215
# 4     214
# 3     213
# 11    207
# 1     202
# 5     193
# 2     181
# Name: count, dtype: int64

# %%
# Month distribution of Movie and TV Shows Added
plt.figure(figsize=(10,12))
plt.subplot(2,2,1)
sns.histplot(df[df.type=='Movie'].release_month, kde=True)
plt.title('Movie-Month')
plt.subplot(2,2,2)
df[df.type=='Movie'].release_month.value_counts().sort_values(ascending=False)[:10].plot(kind='bar')
plt.title('Movie-Month')
plt.subplot(2,2,3)
sns.histplot(df[df.type=='TV Show'].release_month, kde=True)
plt.title('TV Show-Month')
plt.subplot(2,2,4)
df[df.type=='TV Show'].release_month.value_counts().sort_values(ascending=False)[:10].plot(kind='bar')
plt.title('TV Show-Month');

# %%
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water  [Unknown_Director]
# 2      s3  TV Show              Ganglands   [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4      s5  TV Show           Kota Factory  [Unknown_Director]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                     [Unknown_Cast]  [Unknown_Country]
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
# 3 2021-09-24          2021  TV-MA         1
# 4 2021-09-24          2021  TV-MA         2
#
#                                                genre  year_added  \
# 0                                    [Documentaries]        2021
# 1  [International TV Shows, TV Dramas, TV Mysteries]        2021
# 2  [Crime TV Shows, International TV Shows, TV Ac...        2021
# 3                           [Docuseries, Reality TV]        2021
# 4  [International TV Shows, Romantic TV Shows, TV...        2021
#
#    release_week  release_month
# 0            38              9
# 1            38              9
# 2            38              9
# 3            38              9
# 4            38              9

# %%
df['diff']=df.year_added-df.release_year
df.head(5)
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead   [Kirsten Johnson]
# 1      s2  TV Show          Blood & Water  [Unknown_Director]
# 2      s3  TV Show              Ganglands   [Julien Leclercq]
# 3      s4  TV Show  Jailbirds New Orleans  [Unknown_Director]
# 4      s5  TV Show           Kota Factory  [Unknown_Director]
#
#                                                 cast            country  \
# 0                                     [Unknown_Cast]    [United States]
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...     [South Africa]
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  [Unknown_Country]
# 3                                     [Unknown_Cast]  [Unknown_Country]
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...            [India]
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13        90
# 1 2021-09-24          2021  TV-MA         2
# 2 2021-09-24          2021  TV-MA         1
# 3 2021-09-24          2021  TV-MA         1
# 4 2021-09-24          2021  TV-MA         2
#
#                                                genre  year_added  \
# 0                                    [Documentaries]        2021
# 1  [International TV Shows, TV Dramas, TV Mysteries]        2021
# 2  [Crime TV Shows, International TV Shows, TV Ac...        2021
# 3                           [Docuseries, Reality TV]        2021
# 4  [International TV Shows, Romantic TV Shows, TV...        2021
#
#    release_week  release_month  diff
# 0            38              9     1
# 1            38              9     0
# 2            38              9     0
# 3            38              9     0
# 4            38              9     0

# %%
sns.kdeplot(data=df, x='diff');

# %%
df['diff'].value_counts()[-10:], df['diff'].value_counts()[:10]
# Out:
# (diff
#  -46    1
#   93    1
#  -40    1
#  -3     1
#   63    1
#  -48    1
#  -43    1
#  -2     1
#   60    1
#  -38    1
#  Name: count, dtype: int64,
#  diff
#  0    3241
#  1    1585
#  2     714
#  3     491
#  4     367
#  5     261
#  6     251
#  7     187
#  8     185
#  9     161
#  Name: count, dtype: int64)

# %%
plt.figure(figsize=(25,4))
sns.countplot(data=df, x='diff')
plt.xlabel('Difference between Release Year and Year Added');

# %%
df[df.type=='Movie']['diff'].value_counts()[:10]
# Out:
# diff
# 0    1862
# 1    1178
# 2     491
# 3     347
# 4     273
# 5     191
# 6     181
# 8     147
# 7     139
# 9     128
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,4))
sns.countplot(data=df[df.type=='Movie'], x='diff')
plt.xlabel('Difference between Release Year and Year Added (Movies)');

# %%
df[df.type=='TV Show']['diff'].value_counts()[:10]
# Out:
# diff
# 0    1379
# 1     407
# 2     223
# 3     144
# 4      94
# 5      70
# 6      70
# 7      48
# 8      38
# 9      33
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,4))
sns.countplot(data=df[df.type=='TV Show'], x='diff')
plt.xlabel('Difference between Release Year and Year Added (TV Shows)');

# %%
df[df.type=='Movie'].duration.value_counts()[:30]
# Out:
# duration
# 90     152
# 94     146
# 97     146
# 93     146
# 91     144
# 95     137
# 96     130
# 92     129
# 102    122
# 98     120
# 99     118
# 101    116
# 88     116
# 103    114
# 106    111
# 100    108
# 89     106
# 104    104
# 86     103
# 105    101
# 87     101
# 107     98
# 110     97
# 108     87
# 116     80
# 112     74
# 85      73
# 113     69
# 109     69
# 84      68
# Name: count, dtype: int64

# %%
df[df.type=='Movie'].duration.value_counts()[:10].plot(kind='bar')
plt.xlabel('Duration in Minutes (Movies)');

# %%
df[df.type=='TV Show'].duration.value_counts()[:20]
# Out:
# duration
# 1     1793
# 2      425
# 3      199
# 4       95
# 5       65
# 6       33
# 7       23
# 8       17
# 9        9
# 10       7
# 13       3
# 15       2
# 12       2
# 11       2
# 17       1
# Name: count, dtype: int64

# %%
df[df.type=='TV Show'].duration.value_counts()[:20].plot(kind='bar')
plt.xlabel('Duration in number of Seasons (TV Shows)');
